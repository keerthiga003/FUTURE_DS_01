# %%
# %reload_ext sql
# %sql mysql+mysqlconnector://root:root@localhost/dummy

# %%
# %%sql
# select * from dummy
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dummy
# (mysql.connector.errors.ProgrammingError) 1146 (42S02): Table 'dummy.dummy' doesn't exist
# [SQL: select * from dummy]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
# %%sql
# show databases;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dummy
# 5 rows affected.
# [('dummy',),
#  ('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sys',)]

# %%
# %%sql
#
# show databases;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dummy
# 5 rows affected.
# [('dummy',),
#  ('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sys',)]

# %%
# %%sql
# use dummy
